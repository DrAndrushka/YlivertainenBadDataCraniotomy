# %% [markdown]
# -------------------------------------
# # **YLIVERTAINEN Bad Data Craniotomy**
# -------------------------------------

# %% [markdown]
# ----------------------
# ## ⚙️ **SETUP for Greatness** ⚙️
# ----------------------

# %%
from pathlib import Path
import sys
def find_root(marker: str = "predictive_modeling.py"):
    p = Path.cwd().resolve()
    for folder in [p, *p.parents]:
        if (folder / marker).is_file():
            return folder
    raise FileNotFoundError(f"Could not find {marker} above {p}")
root = find_root() # Path to .../ylivertainen
print("Current location:", root.name)
print(root)
repo_root = root.parent  # .../TheLibraryOfCode
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
print("Inserted (times):", sys.path.count(str(root)))
print("Current location:", repo_root.name)


#from ylivertainen._pathing import setup_repo_path
#root = setup_repo_path()
# Out:
# Current location: ylivertainen
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen
# Inserted (times): 0
# Current location: YlivertainenBadDataCraniotomy

# %%
#======================= IMPORT LIBRARIES ========================
#from ylivertainen.aesthetics_helpers import GREEN, YELLOW, ORANGE, RED, BOLD, BLUE, GRAY, RESET
import pandas as pd
from IPython.display import display, Markdown

#=======================🧹 DATA CLEANING 🧹========================
from ylivertainen.cleaning import pre_merge_check
from ylivertainen.cleaning import YlivertainenDataCleaningSurg

#=======================🚧 COHORT 🚧========================
from ylivertainen.config import big_beautiful_print
from ylivertainen.cohort import build_stroke_agreement_cohort

#=======================🙊 DDA 🙊========================
from ylivertainen.dda import YlivertainenDDA

#=======================🎨 EDA 🎨========================
from ylivertainen.eda import YlivertainenEDA

#=======================🔮 PREDICTIVE MODELING 🔮========================
from ylivertainen.predictive_modeling import build_model_frame

#=======================🧙‍♂️ INFERENTIAL 🧙‍♂️========================
from ylivertainen.inferential import YlivertainenInferential

#=======================🤖 PREDICTIVE 🤖========================
from ylivertainen.predictive import YlivertainenPredictive

#=======================💪🧠 AWESOME REPORT 💪🧠========================
from ylivertainen.the_report import YlivertainenTheReport

# %% [markdown]
# ----------------------
# # 🧹 **YLIVERTAINEN DATASURG** 🧹
# ----------------------

# %% [markdown]
# ## **SETUP**

# %% [markdown]
# ### Input CSVs and do a pre-merge check of all the columns

# %%
csvs = pre_merge_check(
    colname_length=25,
    show_dfs=False
    )
# Out:
# Current location: YlivertainenBadDataCraniotomy
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy
# Inserted (times): 1
# Current location: TheLibraryOfCode
# ======================================================================
# testtable_synthetic.csv
# ======================================================================
# `Izsaukuma laiks`
# `Pacienta vecums, gadi`
# `Dzimums, 1 - sieviete, 2- vīrietis`
# `Unnamed: 3`
# `NMP pamata diagnoze: G45.9 -1; I64 - 2; I63.9 - 3`
# `Nogādāšanas laiks PSKUS`
# `GKS skala, 1 - nav izvērtēts`
# `FastTest skala: N Negatīvs - 1; P>60 Pozitīvs, lielo asinsvadu oklūzijas iespējamība ≥ 60% - 2; P<15 Pozitīvs, lielo asinsvadu oklūzijas iespējamība <15% - 3; P>30 Pozitīvs, lielo asinsvadu oklūzijas iespējamība ap 30% - 4; nav izvērtēts - 5`
# `Uzņemšanas rezultāts`
# `Pārvests uz`
# `Karte`
# `Iestāšanās diagnoze`
# `Iestāšanās diagnozes nosaukums`
# `Izrakstīšanas diagnoze`
# `Izrakstīšanas diagnozes nosaukums`
# `Iestāšanās laiks`
# `Izrakstīšanas laiks`
# `Izr_dat`
# `Izr_mēn`
# `Izr_gads`
# `Izr_kustība`
# `Izr_kustības nosaukums`
# `Izr_nodaļa`
# `Izr_nodaļas nosaukums`
# `Izr_profils`
# `Izr_profila nosaukums`
# `synthetic_surnames`
# ===== ✅ Using this file as column name reference ✅ =====

# %% [markdown]
# ### Write the **[COLUMN_RENAME_MAP](../columns_to_canonical.py)**
# - unified column renaming
# - drops columns that are not specified
# - DOES NOT create columns
# ### Pass CSVs into the **DataCleaningSurg**

# %%
cleaning = YlivertainenDataCleaningSurg(csvs)
print(cleaning)
display(cleaning.df.head())
# Out:
# ## 🧩 MERGE SUMMARY
# ---
# **Rows:** `500`  |  **Columns:** `9`
#
# ## 🧱 CANONICAL COLUMNS
# `nmpd_diag`, `izrakstisanas_diag`, `vecums`, `dzimums`, `GKS`, `FastTest`
# `izsaukuma_laiks`, `nogadasana_PSKUS_laiks`, `patient_card_no`
# ---
# ## 🗑️ REMOVED COLUMNS
#
# **testtable_synthetic.csv** (18)
#
# `Iestāšanās diagnoze`, `Iestāšanās diagnozes nosaukums`, `Iestāšanās laiks`, `Izr_dat`, `Izr_gads`, `Izr_kustība`, `Izr_kustības nosaukums`, `Izr_mēn`, `Izr_nodaļa`, `Izr_nodaļas nosaukums`, `Izr_profila nosaukums`, `Izr_profils`, `Izrakstīšanas diagnozes nosaukums`, `Izrakstīšanas laiks`, `Pārvests uz`, `Unnamed: 3`, `Uzņemšanas rezultāts`, `synthetic_surnames`
# ---
# ## 🔁 RENAMED COLUMNS
#
# <span style='color:#4da3ff; font-weight:700;'>===== FastTest =====</span>
#
# FastTest skala: N Negatīvs - 1; P>60 Pozitīvs, lielo asinsvadu oklūzijas iespējamība ≥ 60% - 2; P<15 Pozitīvs, lielo asinsvadu oklūzijas iespējamība <15% - 3; P>30 Pozitīvs, lielo asinsvadu oklūzijas iespējamība ap 30% - 4; nav izvērtēts - 5 🪄 testtable_synthetic.csv
#
# <span style='color:#4da3ff; font-weight:700;'>===== GKS =====</span>
#
# GKS skala, 1 - nav izvērtēts 🪄 testtable_synthetic.csv
#
# <span style='color:#4da3ff; font-weight:700;'>===== dzimums =====</span>
#
# Dzimums, 1 - sieviete, 2- vīrietis 🪄 testtable_synthetic.csv
#
# <span style='color:#4da3ff; font-weight:700;'>===== izrakstisanas_diag =====</span>
#
# Izrakstīšanas diagnoze 🪄 testtable_synthetic.csv
#
# <span style='color:#4da3ff; font-weight:700;'>===== izsaukuma_laiks =====</span>
#
# Izsaukuma laiks 🪄 testtable_synthetic.csv
#
# <span style='color:#4da3ff; font-weight:700;'>===== nmpd_diag =====</span>
#
# NMP pamata diagnoze: G45.9 -1; I64 - 2; I63.9 - 3 🪄 testtable_synthetic.csv
#
# <span style='color:#4da3ff; font-weight:700;'>===== nogadasana_PSKUS_laiks =====</span>
#
# Nogādāšanas laiks PSKUS 🪄 testtable_synthetic.csv
#
# <span style='color:#4da3ff; font-weight:700;'>===== patient_card_no =====</span>
#
# Karte 🪄 testtable_synthetic.csv
#
# <span style='color:#4da3ff; font-weight:700;'>===== vecums =====</span>
#
# Pacienta vecums, gadi 🪄 testtable_synthetic.csv
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# In YlivertainenDataCleaningSurg got passed:
# 1 CSVs:
# - testtable_synthetic.csv
# 500 rows, 9 columns
#    nmpd_diag izrakstisanas_diag   vecums  dzimums  GKS  FastTest  \
# 0        2.0              J18.9  sixnine        1   16         2
# 1        1.0              G45.9       70        1   15         5
# 2        1.0              K35.8       80        2   12         3
# 3        3.0                I64       91        1    8         4
# 4        3.0              G51.0       68        2   10         3
#
#               izsaukuma_laiks nogadasana_PSKUS_laiks patient_card_no
# 0            11.06.2024 03:18    2024-06-11 04:02:00      K202400001
# 1         2025-06-10 16:03:00    2025-06-10 17:19:00      K202500002
# 2         2025-12-28 01:23:00    2025-12-28 02:16:00      K202500003
# 3  thirty first december 2025       18.01.2025 14:51      K202500004
# 4            19/10/2024 22:44    2024-10-20 01:48:00      K202400005

# %% [markdown]
# ----------------------
# ## **WRITE AND APPLY [SCHEMA](../schema.py) and [DERIVED](../schema.py)**
# ----------------------

# %% [markdown]
# - dtypes
# - categories (ordered and non-ordered)
# - replace values
# - make NaN
# - keep or drop (decided after DERIVED acts)
#
# **always match column names**
#
# - match, timedelta, datetime bins
# - base on *derive_from*
# - specify *datetime_units* for datetime bins
#
# **creates new cols**
#
# **afterwards *keep=False* will delete specified cols**

# %%
cleaned_df = cleaning.ylivertainen_janitor(
    apply_all=True,
    id_cols=['patient_card_no', 'nogadasana_PSKUS_laiks'],
    include_first=False,
    drop_dupes=False
    )
# Out:
# ══════════════════════════════════════════════════════════════════════
# 🧱 SCHEMA / COLUMN CHECK
# ──────────────────────────────────────────────────────────────────────
# nmpd_diag successfully found in columns
# izrakstisanas_diag successfully found in columns
# vecums successfully found in columns
# dzimums successfully found in columns
# GKS successfully found in columns
# FastTest successfully found in columns
# izsaukuma_laiks successfully found in columns
# nogadasana_PSKUS_laiks successfully found in columns
# patient_card_no successfully found in columns
# ✔ SCHEMA OK: COLUMN_RENAME_MAP matches SCHEMA
#
# ══════════════════════════════════════════════════════════════════════
# 💧 MISSING VALUES / NaNs
# ──────────────────────────────────────────────────────────────────────
# 16 ⇒ NaN @ GKS | Values that became NaN: 1
# 1 ⇒ NaN @ GKS | Values that became NaN: 60
# 5 ⇒ NaN @ FastTest | Values that became NaN: 83
# ✔ NaN pass:
# replaced values in ['GKS', 'FastTest'] columns
#
# ══════════════════════════════════════════════════════════════════════
# 🐾 REPLACE VALUES
# ──────────────────────────────────────────────────────────────────────
# "1" ⇒ "G45.9" @ nmpd_diag
# "2" ⇒ "I64" @ nmpd_diag
# "3" ⇒ "I63.9" @ nmpd_diag
# "1" ⇒ "sieviete" @ dzimums
# "2" ⇒ "vīrietis" @ dzimums
# ✔ Replaced: All target values replaced
#
# ══════════════════════════════════════════════════════════════════════
# 🧬 DTYPE CONVERSION
# ──────────────────────────────────────────────────────────────────────
# nmpd_diag converted to "Categorical (non-ordered)"
# izrakstisanas_diag converted to "Categorical (non-ordered)"
# vecums converted to "numeric" | Values that became NaN: 1 | List: ['sixnine']
# dzimums converted to "Categorical (non-ordered)"
# GKS converted to "Categorical (ordered)"
# FastTest converted to "Categorical (ordered)"
# izsaukuma_laiks converted to "datetime" | Values that became NaN: 1 | List: ['thirty first december 2025']
# nogadasana_PSKUS_laiks converted to "datetime" | Values that became NaN: 0 | List: []
# patient_card_no converted to "text"
# ✔ Done: all columns converted to target dtypes
#
# ══════════════════════════════════════════════════════════════════════
# 🍼 CREATION OF DERIVED
# ──────────────────────────────────────────────────────────────────────
# ⌛ Created lidzPSKUS_timedelta_minutes derived from the difference between "nogadasana_PSKUS_laiks" and "izsaukuma_laiks"
# MAX: 466655
# MIN: 18 ==> also trashed NEGATIVE timedeltas: 38
# Mean: 15941.315
# STD: 64899.743
#
# 🎯 TIA_match: 7.22%
# of cases labeled as ['G45'] in nmpd_diag
# were also classified in the same family in izrakstisanas_diag
# n = 97 evaluable cases
#
# 🎯 ischemic_match: 15.71%
# of cases labeled as ['I63', 'I64'] in nmpd_diag
# were also classified in the same family in izrakstisanas_diag
# n = 401 evaluable cases
#
# 🎯 any_cerebrovascular_match: 32.13%
# of cases labeled as ['I6', 'G45'] in nmpd_diag
# were also classified in the same family in izrakstisanas_diag
# n = 498 evaluable cases
#
# 📅 Created izsaukuma_laiks_hour derived from  "izsaukuma_laiks"
# Unique count: 24
# Unique first: {3: 28, 23: 27, 4: 26, 13: 25, 15: 25}
# Unique last: {12: 18, 2: 17, 0: 15, 21: 14, 14: 13}
#
# 📅 Created izsaukuma_laiks_dow derived from  "izsaukuma_laiks"
# Unique count: 7
# Unique first: {'Tuesday': 85, 'Monday': 76, 'Wednesday': 72, 'Friday': 72, 'Sunday': 72}
# Unique last: {'Wednesday': 72, 'Friday': 72, 'Sunday': 72, 'Thursday': 66, 'Saturday': 56}
#
# 📅 Created izsaukuma_laiks_workday_bool derived from  "izsaukuma_laiks"
# Unique count: 2
# Uniques: {True: 371, False: 129}
#
# 📅 Created izsaukuma_laiks_month_name derived from  "izsaukuma_laiks"
# Unique count: 12
# Unique first: {'October': 58, 'May': 52, 'April': 46, 'December': 46, 'June': 45}
# Unique last: {'January': 38, 'February': 37, 'August': 36, 'July': 31, 'November': 31}
#
# ✔ Derived: creation process completed
# ══════════════════════════════════════════════════════════════════════
#  ⭕ NaN features Flags
# ──────────────────────────────────────────────────────────────────────
# nmpd_diag has 2 NaNs. Created feature flag column
# ✅ No NaNs found in izrakstisanas_diag
# vecums has 1 NaNs. Created feature flag column
# ✅ No NaNs found in dzimums
# GKS has 61 NaNs. Created feature flag column
# FastTest has 83 NaNs. Created feature flag column
# izsaukuma_laiks has 1 NaNs. Created feature flag column
# ✅ No NaNs found in nogadasana_PSKUS_laiks
# ✅ No NaNs found in patient_card_no
# ✔ NaN feature cols: created NaN feature columns
# ══════════════════════════════════════════════════════════════════════
# 🔍 DUPE SEARCH
# ──────────────────────────────────────────────────────────────────────
# ✅ No duplicates found based on complete normalized ID: ['patient_card_no', 'nogadasana_PSKUS_laiks']
# ✔ Dupe search: no duplicates found based on complete normalized ID: ['patient_card_no', 'nogadasana_PSKUS_laiks']
# Empty DataFrame
# Columns: [nmpd_diag, izrakstisanas_diag, vecums, dzimums, GKS, FastTest, izsaukuma_laiks, nogadasana_PSKUS_laiks, patient_card_no, lidzPSKUS_timedelta_minutes, TIA_match, ischemic_match, any_cerebrovascular_match, izsaukuma_laiks_hour, izsaukuma_laiks_dow, izsaukuma_laiks_workday_bool, izsaukuma_laiks_month_name, nmpd_diag_missing, vecums_missing, GKS_missing, FastTest_missing, izsaukuma_laiks_missing]
# Index: []
# ══════════════════════════════════════════════════════════════════════
# 🧠 DATA CLEANING COMPLETE — FRAME STABLE
# ──────────────────────────────────────────────────────────────────────
# ✔ CLEANED DF ONLINE
#    Shape         : 500 rows x 22 cols
#    Remaining NaNs: 694 cells (6.31%)
#    Status        : noise resected, dtypes aligned, ready for cohort craniotomy 🧠🪓
#
# → Next: pass this straight into cohort — no extra rituals needed.
#   nmpd_diag izrakstisanas_diag  vecums   dzimums  GKS FastTest  \
# 0       I64              J18.9     NaN  sieviete  NaN        2
# 1     G45.9              G45.9    70.0  sieviete   15      NaN
# 2     G45.9              K35.8    80.0  vīrietis   12        3
# 3     I63.9                I64    91.0  sieviete    8        4
# 4     I63.9              G51.0    68.0  vīrietis   10        3
#
#       izsaukuma_laiks nogadasana_PSKUS_laiks patient_card_no  \
# 0 2024-06-11 03:18:00    2024-11-06 04:02:00      K202400001
# 1 2025-10-06 16:03:00    2025-10-06 17:19:00      K202500002
# 2 2025-12-28 01:23:00    2025-12-28 02:16:00      K202500003
# 3                 NaT    2025-01-18 14:51:00      K202500004
# 4 2024-10-19 22:44:00    2024-10-20 01:48:00      K202400005
#
#    lidzPSKUS_timedelta_minutes  TIA_match  ischemic_match  \
# 0                       213164       <NA>           False
# 1                           76       True            <NA>
# 2                           53      False            <NA>
# 3                         <NA>       <NA>            True
# 4                          184       <NA>           False
#
#    any_cerebrovascular_match izsaukuma_laiks_hour izsaukuma_laiks_dow  \
# 0                      False                    3             Tuesday
# 1                       True                   16              Monday
# 2                      False                    1              Sunday
# 3                       True                  NaN                 NaN
# 4                      False                   22            Saturday
#
#    izsaukuma_laiks_workday_bool izsaukuma_laiks_month_name  nmpd_diag_missing  \
# 0                          True                       June              False
# 1                          True                    October              False
# 2                         False                   December              False
# 3                         False                        NaN              False
# 4                         False                    October              False
#
#    vecums_missing  GKS_missing  FastTest_missing  izsaukuma_laiks_missing
# 0            True         True             False                    False
# 1           False        False              True                    False
# 2           False        False             False                    False
# 3           False        False             False                     True
# 4           False        False             False                    False

# %% [markdown]
# ----------------------
# ## **VALUE OVERVIEW**
# ----------------------

# %%
cleaning.explore_values()
# Out:
# ===== vecums =====
# Dtype: int64
# MAX: 104
# MIN: 19
# Mean: 72.992
# STD: 13.674
# NaN count: 0
# ===== lidzPSKUS_timedelta_minutes =====
# Dtype: Int64
# MAX: 245
# Mean: 78.345
# STD: 23.105
# NaN count: 0
# ===== nmpd_diag =====
# Dtype: category
# Unique count: 3
# Uniques: {'I64': 2725, 'G45.9': 841, 'I63.9': 47}
# NaN count: 0
# ===== izrakstisanas_diag =====
# Dtype: category
# Unique count: 437
# Unique first: {'I634': 306, 'I63.4': 285, 'I63.3': 137, 'I633': 132, 'I693': 90}
# Unique last: {'T671': 1, 'T790': 1, 'T796': 1, 'T799': 1, 'Y54.6': 1}
# NaN count: 1235
# ===== dzimums =====
# Dtype: category
# Unique count: 2
# Uniques: {'sieviete': 2128, 'vīrietis': 1485}
# NaN count: 0
# ===== GKS =====
# Dtype: category
# Unique count: 13
# Unique first: {15: 1712, 14: 326, 13: 269, 12: 174, 11: 173}
# Unique last: {6: 34, 3: 27, 7: 26, 5: 15, 4: 9}
# NaN count: 500
# ===== FastTest =====
# Dtype: category
# Unique count: 4
# Uniques: {4: 1046, 3: 695, 2: 673, 1: 511}
# NaN count: 688
# ===== izsaukuma_laiks_hour =====
# Dtype: category
# Unique count: 24
# Unique first: {11: 280, 12: 273, 13: 266, 10: 262, 9: 241}
# Unique last: {0: 39, 2: 36, 4: 33, 1: 32, 3: 22}
# NaN count: 0
# ===== izsaukuma_laiks_dow =====
# Dtype: category
# Unique count: 7
# Unique first: {'Monday': 577, 'Thursday': 541, 'Friday': 515, 'Tuesday': 511, 'Wednesday': 501}
# Unique last: {'Friday': 515, 'Tuesday': 511, 'Wednesday': 501, 'Sunday': 492, 'Saturday': 476}
# NaN count: 0
# ===== izsaukuma_laiks_month_name =====
# Dtype: category
# Unique count: 12
# Unique first: {'March': 338, 'December': 338, 'April': 335, 'November': 317, 'January': 315}
# Unique last: {'September': 292, 'June': 278, 'August': 268, 'July': 257, 'February': 256}
# NaN count: 0
# ===== TIA_match =====
# Dtype: boolean
# Unique count: 2
# Uniques: {np.False_: 340, np.True_: 43}
# NaN count: 3230
# ===== ischemic_match =====
# Dtype: boolean
# Unique count: 2
# Uniques: {np.True_: 1034, np.False_: 961}
# NaN count: 1618
# ===== any_cerebrovascular_match =====
# Dtype: boolean
# Unique count: 2
# Uniques: {np.True_: 1555, np.False_: 823}
# NaN count: 1235
# ===== izsaukuma_laiks_workday_bool =====
# Dtype: bool
# Unique count: 2
# Uniques: {True: 2645, False: 968}
# NaN count: 0
# ===== izsaukuma_laiks =====
# Dtype: datetime64[us]
# NaN count: 0
# Unique count: 3613
# Commonest: {Timestamp('2022-01-23 08:06:25'): 1, Timestamp('2022-03-20 13:27:16'): 1, Timestamp('2022-08-24 17:09:38'): 1, Timestamp('2022-06-05 22:32:45'): 1, Timestamp('2022-02-23 15:58:18'): 1}
# Rarest: {Timestamp('2023-12-27 18:50:34'): 1, Timestamp('2023-12-28 04:34:48'): 1, Timestamp('2023-12-29 08:20:45'): 1, Timestamp('2023-12-31 13:28:13'): 1, Timestamp('2023-12-31 14:46:36'): 1}
# ===== nogadasana_PSKUS_laiks =====
# Dtype: datetime64[us]
# NaN count: 0
# Unique count: 3609
# Commonest: {Timestamp('2022-06-09 13:50:00'): 2, Timestamp('2022-10-12 14:50:00'): 2, Timestamp('2022-11-16 03:30:00'): 2, Timestamp('2023-03-16 20:25:00'): 2, Timestamp('2022-01-23 09:08:00'): 1}
# Rarest: {Timestamp('2023-12-27 20:30:00'): 1, Timestamp('2023-12-28 05:36:00'): 1, Timestamp('2023-12-29 08:49:50'): 1, Timestamp('2023-12-31 14:46:10'): 1, Timestamp('2023-12-31 16:00:29'): 1}
# ===== patient_card_no =====
# Dtype: string
# NaN count: 1235
# Unique count: 2377
# Commonest: {'121732022.0': 2, '30802022.0': 1, '105522022.0': 1, '287252022.0': 1, '197312022.0': 1}
# Rarest: {'435192023.0': 1, '433162023.0': 1, '450312023.0': 1, '449912023.0': 1, '448232023.0': 1}
# ===== izrakstisanas_diag_missing =====
# Dtype: bool
# NaN count: 0
# Unique count: 2
# Commonest: {False: 2378, True: 1235}
# Rarest: {False: 2378, True: 1235}
# ===== GKS_missing =====
# Dtype: bool
# NaN count: 0
# Unique count: 2
# Commonest: {False: 3113, True: 500}
# Rarest: {False: 3113, True: 500}
# ===== FastTest_missing =====
# Dtype: bool
# NaN count: 0
# Unique count: 2
# Commonest: {False: 2925, True: 688}
# Rarest: {False: 2925, True: 688}
# ===== patient_card_no_missing =====
# Dtype: bool
# NaN count: 0
# Unique count: 2
# Commonest: {False: 2378, True: 1235}
# Rarest: {False: 2378, True: 1235}

# %% [markdown]
# ---------------
# ---------------
# ---------------

# %% [markdown]
# --------------------------------------
# # **🪪 INPUT TASKS 🪪**
# --------------------------------------

# %%
# import the tasks from ylivertainen.config
from ylivertainen.config import TIA_MATCH, ISCHEMIC_STROKE_MATCH, ANY_CEREBROVASCULAR_MATCH
# define all tasks here
all_tasks = TIA_MATCH, ISCHEMIC_STROKE_MATCH, ANY_CEREBROVASCULAR_MATCH
# define the current task
current_task = ISCHEMIC_STROKE_MATCH

# %% [markdown]
# --------------------------------------
# # 🚧 **YLIVERTAINEN COHORT** 🚧
# --------------------------------------

# %% [markdown]
# --------------------------
# ## **MODELLING TASKS**
# --------------------------

# %% [markdown]
# print all the beautiful tasks to see their criteria and columns

# %%
big_beautiful_print(current_task)
cohorted_df, metadata = build_stroke_agreement_cohort(cleaned_df, current_task, all_tasks)
# Out:
# 🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹
# 🎯 ACTIVE MODELING TASK
# 🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹🔹
# 🏷️ Name                 → Matching Ischemic Stroke
# 🎯 Target column        → ischemic_match
# ✅ Positive class       → True
# 🧮 Task type            → binary
# 🫡 Inclusion Criteria   → {'ischemic_match': 'non-NaN'}
# ----------------------------------------
# 📢 This TaskConfig is the single source of truth for
#     cohort definition, DDA, EDA, and modeling.
# included_in_cohort
# True     1995
# False    1618
# Name: count, dtype: int64
# cohort_exclusion_reason
# None                 1995
# no_ischemic_match    1618
# Name: count, dtype: int64
#    row_id  target nmpd_diag izrakstisanas_diag  vecums   dzimums GKS FastTest  \
# 0       0   False       I64                N40      92  vīrietis  14        3
# 4       4   False       I64               N390      76  sieviete  15        3
# 5       5   False       I64               E118      85  sieviete  13        4
# 6       6   False       I64               N185      72  sieviete  15        3
# 7       7   False       I64               N390      68  sieviete   9        4
#
#       izsaukuma_laiks nogadasana_PSKUS_laiks patient_card_no  \
# 0 2022-01-23 08:06:25    2022-01-23 09:08:00      30802022.0
# 4 2022-02-23 15:58:18    2022-02-23 17:09:00      73742022.0
# 5 2022-04-02 11:06:04    2022-04-02 12:23:05     123102022.0
# 6 2022-08-16 07:06:40    2022-08-16 08:44:00     276882022.0
# 7 2022-09-13 19:37:27    2022-09-13 20:34:38     310082022.0
#
#    lidzPSKUS_timedelta_minutes izsaukuma_laiks_hour izsaukuma_laiks_dow  \
# 0                           61                    8              Sunday
# 4                           70                   15           Wednesday
# 5                           77                   11            Saturday
# 6                           97                    7             Tuesday
# 7                           57                   19             Tuesday
#
#    izsaukuma_laiks_workday_bool izsaukuma_laiks_month_name  GKS_missing  \
# 0                         False                    January        False
# 4                          True                   February        False
# 5                         False                      April        False
# 6                          True                     August        False
# 7                          True                  September        False
#
#    FastTest_missing                 task_name
# 0             False  Matching Ischemic Stroke
# 4             False  Matching Ischemic Stroke
# 5             False  Matching Ischemic Stroke
# 6             False  Matching Ischemic Stroke
# 7             False  Matching Ischemic Stroke

# %% [markdown]
# ---------------------
# ---------------------
# ---------------------

# %% [markdown]
# ---------------
# # 🙈 **YLIVERTAINEN DDA** 🙈
# ---------------

# %% [markdown]
# ----------------------
# ## **LOAD DATASET**
# ----------------------

# %%
descriptive = YlivertainenDDA(root, cohorted_df, metadata)
descriptive.DDA.columns
# Out:
# Index(['row_id', 'target', 'nmpd_diag', 'izrakstisanas_diag', 'vecums',
#        'dzimums', 'GKS', 'FastTest', 'izsaukuma_laiks',
#        'nogadasana_PSKUS_laiks', 'patient_card_no',
#        'lidzPSKUS_timedelta_minutes', 'izsaukuma_laiks_hour',
#        'izsaukuma_laiks_dow', 'izsaukuma_laiks_workday_bool',
#        'izsaukuma_laiks_month_name', 'GKS_missing', 'FastTest_missing',
#        'task_name'],
#       dtype='str')

# %% [markdown]
# --------------------------------
# ### Exclude unneeded cols
# --------------------------------

# %%
if 'Matching TIA' in metadata['task_name']:
    specific_cols = ['nmpd_diag']
else:
    specific_cols = []

descriptive.keep_from_analysis(
    cols = ['patient_card_no', ] + specific_cols
    )
# Out:
# KEPT FROM ANALYSIS: ['patient_card_no']
# ✅ ALL OTHER COLS WILL BE ANALYSED ✅

# %% [markdown]
# --------------------------------
# ## **DATASET OVERVIEW**
# --------------------------------

# %%
descriptive.dataset_overview(
    id_columns=['row_id']      # <== enter str for ID column name
    )
# Out:
# ===================================================
# 🧨🧨🧨 ========= Rows & Columns ========= 🧨🧨🧨
# ===================================================
# 🏗️ Row count: 1995
# 🏗️ Columns count: 19
#
# ===================================================
# 🧨🧨🧨 ========= Dtype summary ========== 🧨🧨🧨
# ===================================================
# 💈 row_id                       : int64
# 💈 target                       : boolean
# 💈 nmpd_diag                    : category
# 💈 izrakstisanas_diag           : category
# 💈 vecums                       : int64
# 💈 dzimums                      : category
# 💈 GKS                          : category
# 💈 FastTest                     : category
# 💈 izsaukuma_laiks              : datetime64[us]
# 💈 nogadasana_PSKUS_laiks       : datetime64[us]
# 💈 patient_card_no              : string
# 💈 lidzPSKUS_timedelta_minutes  : Int64
# 💈 izsaukuma_laiks_hour         : category
# 💈 izsaukuma_laiks_dow          : category
# 💈 izsaukuma_laiks_workday_bool : bool
# 💈 izsaukuma_laiks_month_name   : category
# 💈 GKS_missing                  : bool
# 💈 FastTest_missing             : bool
# 💈 task_name                    : str
#
# ======================================================
# 🧨🧨🧨 ==== Unique vs Repeat encounters ==== 🧨🧨🧨
# ======================================================
# ☝️ ID columns: row_id
# ☝️ Unique encounters: 1995
# ☝️ Repeat encounters: 0 (0.0%)
# Note: not including the first. Only real value duplicates

# %% [markdown]
# --------------------------------
# ## **UNIVARIATE SUMMARY**
# --------------------------------

# %% [markdown]
# ----------------------
# ### numerical
# ----------------------

# %%
descriptive.analyse_numerical()
# Out:
# ===================================================
# 🔢🔢🔢 ============ NUMERICAL =========== 🔢🔢🔢
# ===================================================
#
# ===== vecums =====
# n: 1995
# n_unique: 70
# Missing %: 0.0%
# MIN: 23.0. MAX: 101.0
# Median: 76.0
# Mean: 74.56
# Trimmed mean: 75.51
# Mode: 84
# IQR: 17.0
# 5%: 51.00. 95%: 92.00
# std: 12.37
# cv: 0.17 ➡️ Low Variability - tight around mean, very consistent
# Skewness: -0.74 ➡️ Left-Skewed. Most data are "high"
# Kurtosis: 0.41 ➡️ Mesokurtic. Normal peak, normal tails. "Goldilocks"
# ===== lidzPSKUS_timedelta_minutes =====
# n: 1995
# n_unique: 128
# Missing %: 0.0%
# MIN: 29.0. MAX: 245.0
# Median: 74.0
# Mean: 77.09
# Trimmed mean: 75.28
# Mode: 67
# IQR: 29.0
# 5%: 46.00. 95%: 117.00
# std: 22.97
# cv: 0.30 ➡️ Low Variability - tight around mean, very consistent
# Skewness: 1.08 ➡️ Right-Skewed. Most data are "low"
# Kurtosis: 2.79 ➡️ Leptokurtic. Many extreme "Black Swan" outliers
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:213: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:213: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# <style type="text/css">
# #T_7939c_row0_col1, #T_7939c_row0_col2, #T_7939c_row0_col3, #T_7939c_row0_col4, #T_7939c_row0_col5, #T_7939c_row0_col7, #T_7939c_row0_col9, #T_7939c_row0_col10, #T_7939c_row0_col12, #T_7939c_row0_col14, #T_7939c_row0_col15, #T_7939c_row0_col16, #T_7939c_row1_col1, #T_7939c_row1_col3, #T_7939c_row1_col6, #T_7939c_row1_col11, #T_7939c_row1_col13 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_7939c_row0_col6, #T_7939c_row0_col11, #T_7939c_row0_col13, #T_7939c_row1_col2, #T_7939c_row1_col4, #T_7939c_row1_col5, #T_7939c_row1_col7, #T_7939c_row1_col9, #T_7939c_row1_col10, #T_7939c_row1_col12, #T_7939c_row1_col14, #T_7939c_row1_col15, #T_7939c_row1_col16 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7939c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7939c_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_7939c_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_7939c_level0_col2" class="col_heading level0 col2" >n_unique</th>
#       <th id="T_7939c_level0_col3" class="col_heading level0 col3" >missing_%</th>
#       <th id="T_7939c_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_7939c_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_7939c_level0_col6" class="col_heading level0 col6" >median</th>
#       <th id="T_7939c_level0_col7" class="col_heading level0 col7" >mean</th>
#       <th id="T_7939c_level0_col8" class="col_heading level0 col8" >mode</th>
#       <th id="T_7939c_level0_col9" class="col_heading level0 col9" >std</th>
#       <th id="T_7939c_level0_col10" class="col_heading level0 col10" >cv</th>
#       <th id="T_7939c_level0_col11" class="col_heading level0 col11" >trimmed_mean</th>
#       <th id="T_7939c_level0_col12" class="col_heading level0 col12" >iqrange</th>
#       <th id="T_7939c_level0_col13" class="col_heading level0 col13" >p_5th</th>
#       <th id="T_7939c_level0_col14" class="col_heading level0 col14" >p_95th</th>
#       <th id="T_7939c_level0_col15" class="col_heading level0 col15" >skewness</th>
#       <th id="T_7939c_level0_col16" class="col_heading level0 col16" >kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7939c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7939c_row0_col0" class="data row0 col0" >vecums</td>
#       <td id="T_7939c_row0_col1" class="data row0 col1" >1995</td>
#       <td id="T_7939c_row0_col2" class="data row0 col2" >70</td>
#       <td id="T_7939c_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_7939c_row0_col4" class="data row0 col4" >101</td>
#       <td id="T_7939c_row0_col5" class="data row0 col5" >23</td>
#       <td id="T_7939c_row0_col6" class="data row0 col6" >76.0</td>
#       <td id="T_7939c_row0_col7" class="data row0 col7" >74.559</td>
#       <td id="T_7939c_row0_col8" class="data row0 col8" >['84']</td>
#       <td id="T_7939c_row0_col9" class="data row0 col9" >12.370</td>
#       <td id="T_7939c_row0_col10" class="data row0 col10" >0.166</td>
#       <td id="T_7939c_row0_col11" class="data row0 col11" >75.511</td>
#       <td id="T_7939c_row0_col12" class="data row0 col12" >17.00</td>
#       <td id="T_7939c_row0_col13" class="data row0 col13" >51.00</td>
#       <td id="T_7939c_row0_col14" class="data row0 col14" >92.00</td>
#       <td id="T_7939c_row0_col15" class="data row0 col15" >-0.74</td>
#       <td id="T_7939c_row0_col16" class="data row0 col16" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_7939c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7939c_row1_col0" class="data row1 col0" >lidzPSKUS_timedelta_minutes</td>
#       <td id="T_7939c_row1_col1" class="data row1 col1" >1995</td>
#       <td id="T_7939c_row1_col2" class="data row1 col2" >128</td>
#       <td id="T_7939c_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_7939c_row1_col4" class="data row1 col4" >245</td>
#       <td id="T_7939c_row1_col5" class="data row1 col5" >29</td>
#       <td id="T_7939c_row1_col6" class="data row1 col6" >74.0</td>
#       <td id="T_7939c_row1_col7" class="data row1 col7" >77.088</td>
#       <td id="T_7939c_row1_col8" class="data row1 col8" >['67']</td>
#       <td id="T_7939c_row1_col9" class="data row1 col9" >22.973</td>
#       <td id="T_7939c_row1_col10" class="data row1 col10" >0.298</td>
#       <td id="T_7939c_row1_col11" class="data row1 col11" >75.279</td>
#       <td id="T_7939c_row1_col12" class="data row1 col12" >29.00</td>
#       <td id="T_7939c_row1_col13" class="data row1 col13" >46.00</td>
#       <td id="T_7939c_row1_col14" class="data row1 col14" >117.00</td>
#       <td id="T_7939c_row1_col15" class="data row1 col15" >1.08</td>
#       <td id="T_7939c_row1_col16" class="data row1 col16" >2.79</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ----------------------
# ### categorical
# ----------------------

# %%
descriptive.analyse_categorical()
# Out:
# ===================================================
# 🚦🚦🚦 ============= CATEGORICAL ============= 🚦🚦🚦
# ===================================================
#
# ===== nmpd_diag =====
# n: 1995
# Unique count: 2
# Cardinality: 2 ➡️ Very low ➡️ Ideal for standard one-hot|tree models
# missing_pct: 0.00%
# First MODE: I64
# Proportion of MODE: 98.30%
# second_mode: I63.9
# second_mode_pct: 1.70%
# rarest: G45.9: 0.00%
# max_class_imbalance: 57.68
# Imbalance ratio: 57.68 ➡️ Extreme imbalance ➡️ Treat as rare-event problem; oversampling / specialized methods likely needed
# median_category: <NA>
# Entropy: 0.12 ➡️ Low Diversity ➡️ Usually binary or heavily skewed (e.g., Gender, Yes/No) ➡️ best action --> Keep. Best for root nodes in decision trees
# Balance: 0.12 ➡️ Heavy Imbalance ➡️ Handle with care. You might need to oversample the rare cases
#
# ===== izrakstisanas_diag =====
# n: 1995
# Unique count: 375
# Cardinality: 375 ➡️ Extreme (ID-like) ➡️ Likely leak/noise ➡️ Treat as ID or drop
# missing_pct: 0.00%
# First MODE: I634
# Proportion of MODE: 13.73%
# second_mode: I63.4
# second_mode_pct: 12.63%
# rarest: T799: 0.00%
# max_class_imbalance: 1.09
# Imbalance ratio: 1.09 ➡️ Classes are similarly frequent ➡️ No special handling needed
# median_category: <NA>
# Entropy: 6.04 ➡️ White Noise ➡️ Every value is equally likely ➡️ best action ➡️ Drop
# Balance: 0.71 ➡️ Broad Diversity ➡️ Rich spread across categories. Usually keep; review for fragmentation if many categories are clinically tiny
#
# ===== GKS =====
# n: 1738
# Unique count: 13
# Cardinality: 13 ➡️ Moderate ➡️ Usually fine; watch for sparse rare levels
# missing_pct: 12.88%
# First MODE: 15
# Proportion of MODE: 43.27%
# second_mode: 14
# second_mode_pct: 12.31%
# rarest: 4: 0.40%
# max_class_imbalance: 3.51
# Imbalance ratio: 3.51 ➡️ Strong top-class dominance ➡️ Consider class weights / resampling for modeling
# median_category: 14
# Entropy: 2.70 ➡️ The Sweet Spot ➡️ Healthy clinical variety ➡️ best action --> GOLDEN. This is the best for ML
# Balance: 0.73 ➡️ Broad Diversity ➡️ Rich spread across categories. Usually keep; review for fragmentation if many categories are clinically tiny
#
# ===== FastTest =====
# n: 1883
# Unique count: 4
# Cardinality: 4 ➡️ Very low ➡️ Ideal for standard one-hot|tree models
# missing_pct: 5.61%
# First MODE: 4
# Proportion of MODE: 40.73%
# second_mode: 2
# second_mode_pct: 28.57%
# rarest: 1: 9.45%
# max_class_imbalance: 1.43
# Imbalance ratio: 1.43 ➡️ Classes are similarly frequent ➡️ No special handling needed
# median_category: 4
# Entropy: 1.84 ➡️ The Sweet Spot ➡️ Healthy clinical variety ➡️ best action --> GOLDEN. This is the best for ML
# Balance: 0.92 ➡️ Near-Uniform Spread ➡️ Values are distributed almost equally. Check whether this reflects true diversity or fragmented noise / ID-like categories
#
# ===== izsaukuma_laiks_hour =====
# n: 1995
# Unique count: 24
# Cardinality: 24 ➡️ High ➡️ Consider grouping rare levels or using target|impact encoding
# missing_pct: 0.00%
# First MODE: 11
# Proportion of MODE: 8.07%
# second_mode: 13
# second_mode_pct: 8.02%
# rarest: 3: 0.65%
# max_class_imbalance: 1.01
# Imbalance ratio: 1.01 ➡️ Classes are similarly frequent ➡️ No special handling needed
# median_category: 13
# Entropy: 4.29 ➡️ High Chaos ➡️ Provides deep detail but can lead to overfitting ➡️ best action --> Group the 24 codes into 5-10 broader categories
# Balance: 0.93 ➡️ Near-Uniform Spread ➡️ Values are distributed almost equally. Check whether this reflects true diversity or fragmented noise / ID-like categories
#
# ===== izsaukuma_laiks_dow =====
# n: 1995
# Unique count: 7
# Cardinality: 7 ➡️ Moderate ➡️ Usually fine; watch for sparse rare levels
# missing_pct: 0.00%
# First MODE: Monday
# Proportion of MODE: 15.64%
# second_mode: Thursday
# second_mode_pct: 15.49%
# rarest: Wednesday: 13.13%
# max_class_imbalance: 1.01
# Imbalance ratio: 1.01 ➡️ Classes are similarly frequent ➡️ No special handling needed
# median_category: Thursday
# Entropy: 2.80 ➡️ The Sweet Spot ➡️ Healthy clinical variety ➡️ best action --> GOLDEN. This is the best for ML
# Balance: 1.00 ➡️ Near-Uniform Spread ➡️ Values are distributed almost equally. Check whether this reflects true diversity or fragmented noise / ID-like categories
#
# ===== izsaukuma_laiks_month_name =====
# n: 1995
# Unique count: 12
# Cardinality: 12 ➡️ Moderate ➡️ Usually fine; watch for sparse rare levels
# missing_pct: 0.00%
# First MODE: March
# Proportion of MODE: 10.23%
# second_mode: November
# second_mode_pct: 9.47%
# rarest: July: 6.42%
# max_class_imbalance: 1.08
# Imbalance ratio: 1.08 ➡️ Classes are similarly frequent ➡️ No special handling needed
# median_category: June
# Entropy: 3.57 ➡️ High Chaos ➡️ Provides deep detail but can lead to overfitting ➡️ best action --> Group the 12 codes into 5-10 broader categories
# Balance: 1.00 ➡️ Near-Uniform Spread ➡️ Values are distributed almost equally. Check whether this reflects true diversity or fragmented noise / ID-like categories
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:392: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:398: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:392: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:398: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:392: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:398: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# <style type="text/css">
# #T_c4d42_row0_col1, #T_c4d42_row0_col7, #T_c4d42_row0_col9, #T_c4d42_row1_col1, #T_c4d42_row1_col2, #T_c4d42_row1_col12, #T_c4d42_row2_col3, #T_c4d42_row3_col8, #T_c4d42_row4_col1, #T_c4d42_row5_col1, #T_c4d42_row5_col11, #T_c4d42_row6_col1, #T_c4d42_row6_col11 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c4d42_row0_col2, #T_c4d42_row0_col3, #T_c4d42_row0_col8, #T_c4d42_row0_col11, #T_c4d42_row0_col12, #T_c4d42_row1_col3, #T_c4d42_row1_col9, #T_c4d42_row2_col1, #T_c4d42_row4_col3, #T_c4d42_row4_col7, #T_c4d42_row4_col9, #T_c4d42_row5_col3, #T_c4d42_row5_col9, #T_c4d42_row6_col3, #T_c4d42_row6_col9 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c4d42_row1_col7 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_c4d42_row1_col8 {
#   background-color: #fc8767;
#   color: #f1f1f1;
# }
# #T_c4d42_row1_col11 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_c4d42_row2_col2 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_c4d42_row2_col7 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_c4d42_row2_col8 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_c4d42_row2_col9 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_c4d42_row2_col11 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_c4d42_row2_col12, #T_c4d42_row3_col3 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_c4d42_row3_col1 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_c4d42_row3_col2, #T_c4d42_row3_col9 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_c4d42_row3_col7 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_c4d42_row3_col11 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_c4d42_row3_col12, #T_c4d42_row6_col8 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_c4d42_row4_col2 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_c4d42_row4_col8 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_c4d42_row4_col11 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_c4d42_row4_col12 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_c4d42_row5_col2 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_c4d42_row5_col7 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_c4d42_row5_col8 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_c4d42_row5_col12 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_c4d42_row6_col2, #T_c4d42_row6_col7 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_c4d42_row6_col12 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c4d42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4d42_level0_col0" class="col_heading level0 col0" >col_name</th>
#       <th id="T_c4d42_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_c4d42_level0_col2" class="col_heading level0 col2" >n_unique</th>
#       <th id="T_c4d42_level0_col3" class="col_heading level0 col3" >missing_pct</th>
#       <th id="T_c4d42_level0_col4" class="col_heading level0 col4" >first_mode</th>
#       <th id="T_c4d42_level0_col5" class="col_heading level0 col5" >second_mode</th>
#       <th id="T_c4d42_level0_col6" class="col_heading level0 col6" >rarest</th>
#       <th id="T_c4d42_level0_col7" class="col_heading level0 col7" >first_mode_pct</th>
#       <th id="T_c4d42_level0_col8" class="col_heading level0 col8" >second_mode_pct</th>
#       <th id="T_c4d42_level0_col9" class="col_heading level0 col9" >max_class_imbalance</th>
#       <th id="T_c4d42_level0_col10" class="col_heading level0 col10" >median_category</th>
#       <th id="T_c4d42_level0_col11" class="col_heading level0 col11" >balance</th>
#       <th id="T_c4d42_level0_col12" class="col_heading level0 col12" >entropy_bin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4d42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4d42_row0_col0" class="data row0 col0" >nmpd_diag</td>
#       <td id="T_c4d42_row0_col1" class="data row0 col1" >1995</td>
#       <td id="T_c4d42_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_c4d42_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_c4d42_row0_col4" class="data row0 col4" >I64</td>
#       <td id="T_c4d42_row0_col5" class="data row0 col5" >I63.9</td>
#       <td id="T_c4d42_row0_col6" class="data row0 col6" >G45.9: 0.00%</td>
#       <td id="T_c4d42_row0_col7" class="data row0 col7" >98.30</td>
#       <td id="T_c4d42_row0_col8" class="data row0 col8" >1.70</td>
#       <td id="T_c4d42_row0_col9" class="data row0 col9" >57.68</td>
#       <td id="T_c4d42_row0_col10" class="data row0 col10" ><NA></td>
#       <td id="T_c4d42_row0_col11" class="data row0 col11" >0.12</td>
#       <td id="T_c4d42_row0_col12" class="data row0 col12" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_c4d42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4d42_row1_col0" class="data row1 col0" >izrakstisanas_diag</td>
#       <td id="T_c4d42_row1_col1" class="data row1 col1" >1995</td>
#       <td id="T_c4d42_row1_col2" class="data row1 col2" >375</td>
#       <td id="T_c4d42_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_c4d42_row1_col4" class="data row1 col4" >I634</td>
#       <td id="T_c4d42_row1_col5" class="data row1 col5" >I63.4</td>
#       <td id="T_c4d42_row1_col6" class="data row1 col6" >T799: 0.00%</td>
#       <td id="T_c4d42_row1_col7" class="data row1 col7" >13.73</td>
#       <td id="T_c4d42_row1_col8" class="data row1 col8" >12.63</td>
#       <td id="T_c4d42_row1_col9" class="data row1 col9" >1.09</td>
#       <td id="T_c4d42_row1_col10" class="data row1 col10" ><NA></td>
#       <td id="T_c4d42_row1_col11" class="data row1 col11" >0.71</td>
#       <td id="T_c4d42_row1_col12" class="data row1 col12" >6.04</td>
#     </tr>
#     <tr>
#       <th id="T_c4d42_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c4d42_row2_col0" class="data row2 col0" >GKS</td>
#       <td id="T_c4d42_row2_col1" class="data row2 col1" >1738</td>
#       <td id="T_c4d42_row2_col2" class="data row2 col2" >13</td>
#       <td id="T_c4d42_row2_col3" class="data row2 col3" >12.88</td>
#       <td id="T_c4d42_row2_col4" class="data row2 col4" >15</td>
#       <td id="T_c4d42_row2_col5" class="data row2 col5" >14</td>
#       <td id="T_c4d42_row2_col6" class="data row2 col6" >4: 0.40%</td>
#       <td id="T_c4d42_row2_col7" class="data row2 col7" >43.27</td>
#       <td id="T_c4d42_row2_col8" class="data row2 col8" >12.31</td>
#       <td id="T_c4d42_row2_col9" class="data row2 col9" >3.51</td>
#       <td id="T_c4d42_row2_col10" class="data row2 col10" >14</td>
#       <td id="T_c4d42_row2_col11" class="data row2 col11" >0.73</td>
#       <td id="T_c4d42_row2_col12" class="data row2 col12" >2.70</td>
#     </tr>
#     <tr>
#       <th id="T_c4d42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c4d42_row3_col0" class="data row3 col0" >FastTest</td>
#       <td id="T_c4d42_row3_col1" class="data row3 col1" >1883</td>
#       <td id="T_c4d42_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_c4d42_row3_col3" class="data row3 col3" >5.61</td>
#       <td id="T_c4d42_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_c4d42_row3_col5" class="data row3 col5" >2</td>
#       <td id="T_c4d42_row3_col6" class="data row3 col6" >1: 9.45%</td>
#       <td id="T_c4d42_row3_col7" class="data row3 col7" >40.73</td>
#       <td id="T_c4d42_row3_col8" class="data row3 col8" >28.57</td>
#       <td id="T_c4d42_row3_col9" class="data row3 col9" >1.43</td>
#       <td id="T_c4d42_row3_col10" class="data row3 col10" >4</td>
#       <td id="T_c4d42_row3_col11" class="data row3 col11" >0.92</td>
#       <td id="T_c4d42_row3_col12" class="data row3 col12" >1.84</td>
#     </tr>
#     <tr>
#       <th id="T_c4d42_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c4d42_row4_col0" class="data row4 col0" >izsaukuma_laiks_hour</td>
#       <td id="T_c4d42_row4_col1" class="data row4 col1" >1995</td>
#       <td id="T_c4d42_row4_col2" class="data row4 col2" >24</td>
#       <td id="T_c4d42_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_c4d42_row4_col4"

# %% [markdown]
# ----------------------
# ### binary
# ----------------------

# %%
descriptive.analyse_binary()
# Out:
# ===================================================
# 🚦🚦🚦 ================ BINARY =============== 🚦🚦🚦
# ===================================================
#
# ===== dzimums =====
# n: 1995
# Missing %: 0.00%
# p1 (sieviete): 0.59
# p0 (vīrietis): 0.41
# MODE: sieviete
# MODE %: 59.50%
# Balance: 0.81 ➡️ Healthy Balance - great for modeling
# Entropy:0.97 ➡️ High entropy - close to 50/50. Maximally informative for splits; great for ML
#
# ===== izsaukuma_laiks_workday_bool =====
# n: 1995
# Missing %: 0.00%
# p1 (True): 0.72
# p0 (False): 0.28
# MODE: True
# MODE %: 72.33%
# Balance: 0.55 ➡️ Moderate Imbalance - generally fine, but watch rare class
# Entropy:0.85 ➡️ High entropy - close to 50/50. Maximally informative for splits; great for ML
#
# ===== GKS_missing =====
# n: 1995
# p1 (False): 0.87
# p0 (True): 0.13
# MODE: False
# MODE %: 87.12%
# Balance: 0.26 ➡️ Heavy Imbalance - rare positives/negatives. Handle with care
# Entropy:0.55 ➡️ Moderate entropy - decent mix, but still some skew. Often fine for modeling
#
# ===== FastTest_missing =====
# n: 1995
# p1 (False): 0.94
# p0 (True): 0.06
# MODE: False
# MODE %: 94.39%
# Balance: 0.11 ➡️ Heavy Imbalance - rare positives/negatives. Handle with care
# Entropy:0.31 ➡️ Moderate entropy - decent mix, but still some skew. Often fine for modeling
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:529: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:529: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:529: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/dda.py:529: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# <style type="text/css">
# #T_7fbfc_row0_col2, #T_7fbfc_row0_col3, #T_7fbfc_row0_col6, #T_7fbfc_row1_col2, #T_7fbfc_row2_col2, #T_7fbfc_row3_col2, #T_7fbfc_row3_col4, #T_7fbfc_row3_col7, #T_7fbfc_row3_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_7fbfc_row0_col4, #T_7fbfc_row0_col7, #T_7fbfc_row0_col8, #T_7fbfc_row3_col3, #T_7fbfc_row3_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_7fbfc_row1_col3, #T_7fbfc_row1_col6 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_7fbfc_row1_col4, #T_7fbfc_row1_col7 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_7fbfc_row1_col8 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_7fbfc_row2_col3, #T_7fbfc_row2_col6 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_7fbfc_row2_col4, #T_7fbfc_row2_col7 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_7fbfc_row2_col8 {
#   background-color: #fc9576;
#   color: #000000;
# }
# </style>
# <table id="T_7fbfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fbfc_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_7fbfc_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_7fbfc_level0_col2" class="col_heading level0 col2" >missing_pct</th>
#       <th id="T_7fbfc_level0_col3" class="col_heading level0 col3" >p1</th>
#       <th id="T_7fbfc_level0_col4" class="col_heading level0 col4" >p0</th>
#       <th id="T_7fbfc_level0_col5" class="col_heading level0 col5" >mode</th>
#       <th id="T_7fbfc_level0_col6" class="col_heading level0 col6" >mode_pct</th>
#       <th id="T_7fbfc_level0_col7" class="col_heading level0 col7" >balance</th>
#       <th id="T_7fbfc_level0_col8" class="col_heading level0 col8" >entropy_bin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fbfc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7fbfc_row0_col0" class="data row0 col0" >dzimums</td>
#       <td id="T_7fbfc_row0_col1" class="data row0 col1" >1995</td>
#       <td id="T_7fbfc_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_7fbfc_row0_col3" class="data row0 col3" >0.595</td>
#       <td id="T_7fbfc_row0_col4" class="data row0 col4" >0.405</td>
#       <td id="T_7fbfc_row0_col5" class="data row0 col5" >sieviete</td>
#       <td id="T_7fbfc_row0_col6" class="data row0 col6" >59.499</td>
#       <td id="T_7fbfc_row0_col7" class="data row0 col7" >0.810</td>
#       <td id="T_7fbfc_row0_col8" class="data row0 col8" >0.974</td>
#     </tr>
#     <tr>
#       <th id="T_7fbfc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7fbfc_row1_col0" class="data row1 col0" >izsaukuma_laiks_workday_bool</td>
#       <td id="T_7fbfc_row1_col1" class="data row1 col1" >1995</td>
#       <td id="T_7fbfc_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_7fbfc_row1_col3" class="data row1 col3" >0.723</td>
#       <td id="T_7fbfc_row1_col4" class="data row1 col4" >0.277</td>
#       <td id="T_7fbfc_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_7fbfc_row1_col6" class="data row1 col6" >72.331</td>
#       <td id="T_7fbfc_row1_col7" class="data row1 col7" >0.553</td>
#       <td id="T_7fbfc_row1_col8" class="data row1 col8" >0.851</td>
#     </tr>
#     <tr>
#       <th id="T_7fbfc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7fbfc_row2_col0" class="data row2 col0" >GKS_missing</td>
#       <td id="T_7fbfc_row2_col1" class="data row2 col1" >1995</td>
#       <td id="T_7fbfc_row2_col2" class="data row2 col2" ><NA></td>
#       <td id="T_7fbfc_row2_col3" class="data row2 col3" >0.871</td>
#       <td id="T_7fbfc_row2_col4" class="data row2 col4" >0.129</td>
#       <td id="T_7fbfc_row2_col5" class="data row2 col5" >False</td>
#       <td id="T_7fbfc_row2_col6" class="data row2 col6" >87.118</td>
#       <td id="T_7fbfc_row2_col7" class="data row2 col7" >0.258</td>
#       <td id="T_7fbfc_row2_col8" class="data row2 col8" >0.554</td>
#     </tr>
#     <tr>
#       <th id="T_7fbfc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7fbfc_row3_col0" class="data row3 col0" >FastTest_missing</td>
#       <td id="T_7fbfc_row3_col1" class="data row3 col1" >1995</td>
#       <td id="T_7fbfc_row3_col2" class="data row3 col2" ><NA></td>
#       <td id="T_7fbfc_row3_col3" class="data row3 col3" >0.944</td>
#       <td id="T_7fbfc_row3_col4" class="data row3 col4" >0.056</td>
#       <td id="T_7fbfc_row3_col5" class="data row3 col5" >False</td>
#       <td id="T_7fbfc_row3_col6" class="data row3 col6" >94.386</td>
#       <td id="T_7fbfc_row3_col7" class="data row3 col7" >0.112</td>
#       <td id="T_7fbfc_row3_col8" class="data row3 col8" >0.312</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ----------------------
# ### Export all the tables
# ----------------------

# %%
descriptive.export_all_overviews(
    export=False
    )
# Out:
# 🔄 Gonna save in: ylivertainen/reports/tables/
# 🔄 FORMAT: pickle
#
# 🔄 Numerical DDA Overview: (DDA_numerical_overview)Matching Ischemic Stroke
# 🔄 Categorical DDA Overview: (DDA_categorical_overview)Matching Ischemic Stroke
# 🔄 Binary DDA Overview: (DDA_binary_overview)Matching Ischemic Stroke
# ===== export=True to save =====
#
# ══════════════════════════════════════════════════════════════════════
# 🧠 DDA STAGE COMPLETE — BRAIN MAP LOCKED IN
# ──────────────────────────────────────────────────────────────────────
# ✔ DDA FRAME READY FOR EDA ANGIO SUITE
#    Shape         : 1995 rows x 19 cols
#    Remaining NaNs: 369 cells (0.97%)
#    Contents      : variable summaries, distributions, missingness map — all scrubbed and labeled.
#
# → Next hop: EDA class for full association hunting and leakage checks.
#    row_id  target nmpd_diag izrakstisanas_diag  vecums   dzimums GKS FastTest  \
# 0       0   False       I64                N40      92  vīrietis  14        3
# 4       4   False       I64               N390      76  sieviete  15        3
# 5       5   False       I64               E118      85  sieviete  13        4
# 6       6   False       I64               N185      72  sieviete  15        3
# 7       7   False       I64               N390      68  sieviete   9        4
#
#       izsaukuma_laiks nogadasana_PSKUS_laiks patient_card_no  \
# 0 2022-01-23 08:06:25    2022-01-23 09:08:00      30802022.0
# 4 2022-02-23 15:58:18    2022-02-23 17:09:00      73742022.0
# 5 2022-04-02 11:06:04    2022-04-02 12:23:05     123102022.0
# 6 2022-08-16 07:06:40    2022-08-16 08:44:00     276882022.0
# 7 2022-09-13 19:37:27    2022-09-13 20:34:38     310082022.0
#
#    lidzPSKUS_timedelta_minutes izsaukuma_laiks_hour izsaukuma_laiks_dow  \
# 0                           61                    8              Sunday
# 4                           70                   15           Wednesday
# 5                           77                   11            Saturday
# 6                           97                    7             Tuesday
# 7                           57                   19             Tuesday
#
#    izsaukuma_laiks_workday_bool izsaukuma_laiks_month_name  GKS_missing  \
# 0                         False                    January        False
# 4                          True                   February        False
# 5                         False                      April        False
# 6                          True                     August        False
# 7                          True                  September        False
#
#    FastTest_missing                 task_name
# 0             False  Matching Ischemic Stroke
# 4             False  Matching Ischemic Stroke
# 5             False  Matching Ischemic Stroke
# 6             False  Matching Ischemic Stroke
# 7             False  Matching Ischemic Stroke

# %% [markdown]
# -------------
# # 📊🎨 **YLIVERTAINEN EDA** 🎨📊
# -------------

# %% [markdown]
# ----------------------
# ## **STUDY AIM AND QUESTIONS**
# ----------------------

# %% [markdown]
# -------------------------------------
# ### **COHORT DEFINITION**
# - **Source:** PSKUS
# - **Time window:** Year 2022-2023
# - **Row:** 1 unique patient case
# -------------------------------------
# ### **KEY INCLUSION SCOPE**
# - "NMP pamata diagnoze": I63.9, I64, G45.9
# - "Izrakstīšanas diagnozes kods"
# -------------------------------------
# ### **STUDY AIM**
# - **EXPLORE:**
#     - "NMP pamata diagnoze" vs "Izrakstīšanas diagnozes kods"
# - **FIND:**
#     - Agreement/Mismatch
# - **ADDITIONAL AIMS:**
#     - Identify predictors associated with diagnostic agreement or mismatch
# -------------------------------------
# ### **STUDY CONTEXT**
#
# <p>This notebook explores agreement between prehospital stroke-related diagnosis and discharge diagnosis in PSKUS 2022-2023 data in patients.
# <p>The goal is to understand how often prehospital diagnosis aligns with hospital discharge diagnosis and which patient or process factors may be associated with disagreement
#
# -------------------------------------

# %% [markdown]
# ----------------------
# ## **LOAD DATASET**
# ----------------------

# %%
exploratory = YlivertainenEDA(root, cohorted_df, metadata)
display(exploratory.EDA.head(1))
# Out:
#    row_id  target nmpd_diag izrakstisanas_diag  vecums   dzimums GKS FastTest  \
# 0       0   False       I64                N40      92  vīrietis  14        3
#
#       izsaukuma_laiks nogadasana_PSKUS_laiks patient_card_no  \
# 0 2022-01-23 08:06:25    2022-01-23 09:08:00      30802022.0
#
#    lidzPSKUS_timedelta_minutes izsaukuma_laiks_hour izsaukuma_laiks_dow  \
# 0                           61                    8              Sunday
#
#    izsaukuma_laiks_workday_bool izsaukuma_laiks_month_name  GKS_missing  \
# 0                         False                    January        False
#
#    FastTest_missing                 task_name
# 0             False  Matching Ischemic Stroke

# %% [markdown]
# ----------------------
# ## **WHITELIST COLUMNS FOR ANALYSIS**
# ----------------------

# %%
# ============ Defining features. Choosing columns to remain ============
exploratory.whitelist_columns(
    predictors = [
        'nmpd_diag', 'vecums', 'dzimums',
        'GKS', 'FastTest',
        'lidzPSKUS_timedelta_minutes',
        'izsaukuma_laiks_hour', 'izsaukuma_laiks_dow',
        'izsaukuma_laiks_workday_bool', 'izsaukuma_laiks_month_name',
        'GKS_missing', 'FastTest_missing'
        ],
    numerical_continuous = ['vecums']
    )
# Out:
# ✅ All cols classified
# ===== Main variables =====
# Target: Matching Ischemic Stroke AS "target" (boolean)
# Predictors: 12 total
# - Numerical Continuous: vecums
# - Binary: izsaukuma_laiks_workday_bool, GKS_missing, FastTest_missing
# - Categorical Nominal: nmpd_diag, dzimums
# - Categorical Ordinal: GKS, FastTest, izsaukuma_laiks_hour, izsaukuma_laiks_dow, izsaukuma_laiks_month_name
# - Time To Event: lidzPSKUS_timedelta_minutes

# %% [markdown]
# ----------------------
# ## **ASSOCIATIONS & FEATURE DECISIONS**
# ----------------------

# %%
if 'Matching TIA' in exploratory.task_name:
    leakage_vars = {'nmpd_diag',}
else:
    leakage_vars = None         # list of str
missingness_dict = None         # pd.DataFrame([{"column_name": "nmpd_diag", "missingness_type": "missing", "inferred_type": "categorical"}, {...}])
redundancy_pairs = None         # pd.DataFrame([{"var_a": "age", "var_b": "age_years", "preferred_keep": "age"}, {...}])

# %%
exploratory.build_associations_table(leakage_vars)
# Out:
#    analysis_col                 predictor_col analysis_type  \
# 0        target                        vecums        binary
# 1        target  izsaukuma_laiks_workday_bool        binary
# 2        target                   GKS_missing        binary
# 3        target              FastTest_missing        binary
# 4        target                     nmpd_diag        binary
# 5        target                       dzimums        binary
# 6        target                           GKS        binary
# 7        target                      FastTest        binary
# 8        target          izsaukuma_laiks_hour        binary
# 9        target           izsaukuma_laiks_dow        binary
# 10       target    izsaukuma_laiks_month_name        binary
# 11       target   lidzPSKUS_timedelta_minutes        binary
#
#          predictor_type         pair_type  n_used  analysis_excluded_n  \
# 0            continuous  predictor_target    1995                    0
# 1                binary  predictor_target    1995                    0
# 2                binary  predictor_target    1995                    0
# 3                binary  predictor_target    1995                    0
# 4   categorical_nominal  predictor_target    1995                    0
# 5   categorical_nominal  predictor_target    1995                    0
# 6   categorical_ordinal  predictor_target    1738                    0
# 7   categorical_ordinal  predictor_target    1883                    0
# 8   categorical_ordinal  predictor_target    1995                    0
# 9   categorical_ordinal  predictor_target    1995                    0
# 10  categorical_ordinal  predictor_target    1995                    0
# 11        time_to_event  predictor_target    1995                    0
#
#     predictor_missing_n status  note       test_name  test_stat   p_value  \
# 0                     0     ok  <NA>  point_biserial   0.046965  0.035943
# 1                     0     ok  <NA>            chi2   0.194282  0.659376
# 2                     0     ok  <NA>            chi2    0.50214  0.478561
# 3                     0     ok  <NA>            chi2  14.480081  0.000142
# 4                     0     ok  <NA>            chi2   0.539687  0.462563
# 5                     0     ok  <NA>            chi2   0.571602  0.449623
# 6                   257     ok  <NA>            chi2  66.700514       0.0
# 7                   112     ok  <NA>            chi2  16.672362  0.000825
# 8                     0     ok  <NA>            chi2  26.331998  0.285445
# 9                     0     ok  <NA>            chi2   7.857558  0.248726
# 10                    0     ok  <NA>            chi2   9.418841  0.583291
# 11                    0     ok  <NA>  point_biserial  -0.177456       0.0
#
#    effect_size_name  effect_size p_value_note  leakage_flag
# 0                 r     0.046965     sig_0.05         False
# 1         cramers_v     0.009868           ns         False
# 2         cramers_v     0.015865           ns         False
# 3         cramers_v     0.085195    sig_0.001         False
# 4         cramers_v     0.016447           ns         False
# 5         cramers_v     0.016927           ns         False
# 6         cramers_v     0.195902    sig_0.001         False
# 7         cramers_v     0.094096    sig_0.001         False
# 8         cramers_v     0.114887           ns         False
# 9         cramers_v     0.062758           ns         False
# 10        cramers_v     0.068711           ns         False
# 11                r    -0.177456    sig_0.001         False

# %%
feature_decisions_df = exploratory.build_feature_decisions_table(missingness_dict, leakage_vars, redundancy_pairs)
# Out:
#                      column_name       role     dtype        inferred_type  \
# 0                         target     target   boolean              unknown
# 1                         vecums  predictor     int64           continuous
# 2   izsaukuma_laiks_workday_bool  predictor      bool               binary
# 3                      nmpd_diag  predictor  category  categorical_nominal
# 4                        dzimums  predictor  category  categorical_nominal
# 5                            GKS  predictor  category  categorical_ordinal
# 6                       FastTest  predictor  category  categorical_ordinal
# 7           izsaukuma_laiks_hour  predictor  category  categorical_ordinal
# 8            izsaukuma_laiks_dow  predictor  category  categorical_ordinal
# 9     izsaukuma_laiks_month_name  predictor  category  categorical_ordinal
# 10   lidzPSKUS_timedelta_minutes  predictor     Int64        time_to_event
# 11                        row_id         id     int64              unknown
#
#     missing_pct drop_reason action missing_action              notes
# 0           0.0               keep     no_missing               <NA>
# 1           0.0               keep     no_missing               <NA>
# 2           0.0               keep     no_missing               <NA>
# 3           0.0               keep     no_missing               <NA>
# 4           0.0               keep     no_missing               <NA>
# 5     12.882206               keep  simple_impute               <NA>
# 6      5.614035               keep  simple_impute               <NA>
# 7           0.0               keep     no_missing               <NA>
# 8           0.0               keep     no_missing               <NA>
# 9           0.0               keep     no_missing               <NA>
# 10          0.0               keep     no_missing               <NA>
# 11          0.0               keep     no_missing  identifier_column

# %% [markdown]
# ----------------------
# ### EXPORT TABLES
# ----------------------

# %%
exploratory.export_both_tables(
    export=False
    )
# Out:
# 🔄 Gonna save in: ylivertainen/reports/tables/
# 🔄 Feature Decisions Table: (EDA_feature_decisions_table)Matching Ischemic Stroke
# 🔄 Associations Table: (EDA_associations_table)Matching Ischemic Stroke
# 🔄 FORMAT: pickle
# ===== export=True to save =====
#
# ══════════════════════════════════════════════════════════════════════
# 🧠 EDA COMPLETE — FULL BRAIN ANGIOGRAM ACQUIRED — MATCHING ISCHEMIC STROKE
# ──────────────────────────────────────────────────────────────────────
# ✔ EDA FRAME ONLINE FOR DECISION-MAKING
#    Shape         : 1995 rows x 14 cols
#    Remaining NaNs: 369 cells (1.32%)
#    Contents      : associations mapped, redundancy flagged, leakage suspects tagged.
#
# → Neurosurgical note: this is the point where others stop and
#                         you push through —
#                           turn this map into hard feature decisions and a clean model frame.
#    target  vecums  izsaukuma_laiks_workday_bool  GKS_missing  \
# 0   False      92                         False        False
#
#    FastTest_missing nmpd_diag   dzimums GKS FastTest izsaukuma_laiks_hour  \
# 0             False       I64  vīrietis  14        3                    8
#
#   izsaukuma_laiks_dow izsaukuma_laiks_month_name  lidzPSKUS_timedelta_minutes  \
# 0              Sunday                    January                           61
#
#    row_id
# 0       0

# %% [markdown]
# -------------
# # 🔮 **YLIVERTAINEN PREDICTIVE MODELING** 🔮
# -------------

# %%
df_model = build_model_frame(
    root,
    cohorted_df,
    feature_decisions_df,
    metadata,
    export=False
    )
# Out:
# <style type="text/css">
# #T_f1e9c_row0_col0, #T_f1e9c_row0_col1, #T_f1e9c_row0_col2, #T_f1e9c_row0_col3, #T_f1e9c_row0_col4, #T_f1e9c_row0_col5, #T_f1e9c_row0_col6, #T_f1e9c_row0_col7, #T_f1e9c_row0_col8 {
#   color: #FF8C00;
# }
# #T_f1e9c_row1_col0, #T_f1e9c_row1_col1, #T_f1e9c_row1_col2, #T_f1e9c_row1_col3, #T_f1e9c_row1_col4, #T_f1e9c_row1_col5, #T_f1e9c_row1_col6, #T_f1e9c_row1_col7, #T_f1e9c_row1_col8, #T_f1e9c_row2_col0, #T_f1e9c_row2_col1, #T_f1e9c_row2_col2, #T_f1e9c_row2_col3, #T_f1e9c_row2_col4, #T_f1e9c_row2_col5, #T_f1e9c_row2_col6, #T_f1e9c_row2_col7, #T_f1e9c_row2_col8, #T_f1e9c_row3_col0, #T_f1e9c_row3_col1, #T_f1e9c_row3_col2, #T_f1e9c_row3_col3, #T_f1e9c_row3_col4, #T_f1e9c_row3_col5, #T_f1e9c_row3_col6, #T_f1e9c_row3_col7, #T_f1e9c_row3_col8, #T_f1e9c_row4_col0, #T_f1e9c_row4_col1, #T_f1e9c_row4_col2, #T_f1e9c_row4_col3, #T_f1e9c_row4_col4, #T_f1e9c_row4_col5, #T_f1e9c_row4_col6, #T_f1e9c_row4_col7, #T_f1e9c_row4_col8, #T_f1e9c_row7_col0, #T_f1e9c_row7_col1, #T_f1e9c_row7_col2, #T_f1e9c_row7_col3, #T_f1e9c_row7_col4, #T_f1e9c_row7_col5, #T_f1e9c_row7_col6, #T_f1e9c_row7_col7, #T_f1e9c_row7_col8, #T_f1e9c_row8_col0, #T_f1e9c_row8_col1, #T_f1e9c_row8_col2, #T_f1e9c_row8_col3, #T_f1e9c_row8_col4, #T_f1e9c_row8_col5, #T_f1e9c_row8_col6, #T_f1e9c_row8_col7, #T_f1e9c_row8_col8, #T_f1e9c_row9_col0, #T_f1e9c_row9_col1, #T_f1e9c_row9_col2, #T_f1e9c_row9_col3, #T_f1e9c_row9_col4, #T_f1e9c_row9_col5, #T_f1e9c_row9_col6, #T_f1e9c_row9_col7, #T_f1e9c_row9_col8, #T_f1e9c_row10_col0, #T_f1e9c_row10_col1, #T_f1e9c_row10_col2, #T_f1e9c_row10_col3, #T_f1e9c_row10_col4, #T_f1e9c_row10_col5, #T_f1e9c_row10_col6, #T_f1e9c_row10_col7, #T_f1e9c_row10_col8 {
#   color: #1E9101;
# }
# #T_f1e9c_row5_col0, #T_f1e9c_row5_col1, #T_f1e9c_row5_col2, #T_f1e9c_row5_col3, #T_f1e9c_row5_col4, #T_f1e9c_row5_col5, #T_f1e9c_row5_col6, #T_f1e9c_row5_col7, #T_f1e9c_row5_col8, #T_f1e9c_row6_col0, #T_f1e9c_row6_col1, #T_f1e9c_row6_col2, #T_f1e9c_row6_col3, #T_f1e9c_row6_col4, #T_f1e9c_row6_col5, #T_f1e9c_row6_col6, #T_f1e9c_row6_col7, #T_f1e9c_row6_col8 {
#   color: #CBB255;
# }
# #T_f1e9c_row11_col0, #T_f1e9c_row11_col1, #T_f1e9c_row11_col2, #T_f1e9c_row11_col3, #T_f1e9c_row11_col4, #T_f1e9c_row11_col5, #T_f1e9c_row11_col6, #T_f1e9c_row11_col7, #T_f1e9c_row11_col8 {
#   color: #818181;
# }
# </style>
# <table id="T_f1e9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1e9c_level0_col0" class="col_heading level0 col0" >column_name</th>
#       <th id="T_f1e9c_level0_col1" class="col_heading level0 col1" >role</th>
#       <th id="T_f1e9c_level0_col2" class="col_heading level0 col2" >dtype</th>
#       <th id="T_f1e9c_level0_col3" class="col_heading level0 col3" >inferred_type</th>
#       <th id="T_f1e9c_level0_col4" class="col_heading level0 col4" >missing_pct</th>
#       <th id="T_f1e9c_level0_col5" class="col_heading level0 col5" >drop_reason</th>
#       <th id="T_f1e9c_level0_col6" class="col_heading level0 col6" >action</th>
#       <th id="T_f1e9c_level0_col7" class="col_heading level0 col7" >missing_action</th>
#       <th id="T_f1e9c_level0_col8" class="col_heading level0 col8" >notes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1e9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1e9c_row0_col0" class="data row0 col0" >target</td>
#       <td id="T_f1e9c_row0_col1" class="data row0 col1" >target</td>
#       <td id="T_f1e9c_row0_col2" class="data row0 col2" >boolean</td>
#       <td id="T_f1e9c_row0_col3" class="data row0 col3" >unknown</td>
#       <td id="T_f1e9c_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_f1e9c_row0_col5" class="data row0 col5" ></td>
#       <td id="T_f1e9c_row0_col6" class="data row0 col6" >keep</td>
#       <td id="T_f1e9c_row0_col7" class="data row0 col7" >no_missing</td>
#       <td id="T_f1e9c_row0_col8" class="data row0 col8" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_f1e9c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1e9c_row1_col0" class="data row1 col0" >vecums</td>
#       <td id="T_f1e9c_row1_col1" class="data row1 col1" >predictor</td>
#       <td id="T_f1e9c_row1_col2" class="data row1 col2" >int64</td>
#       <td id="T_f1e9c_row1_col3" class="data row1 col3" >continuous</td>
#       <td id="T_f1e9c_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_f1e9c_row1_col5" class="data row1 col5" ></td>
#       <td id="T_f1e9c_row1_col6" class="data row1 col6" >keep</td>
#       <td id="T_f1e9c_row1_col7" class="data row1 col7" >no_missing</td>
#       <td id="T_f1e9c_row1_col8" class="data row1 col8" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_f1e9c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f1e9c_row2_col0" class="data row2 col0" >izsaukuma_laiks_workday_bool</td>
#       <td id="T_f1e9c_row2_col1" class="data row2 col1" >predictor</td>
#       <td id="T_f1e9c_row2_col2" class="data row2 col2" >bool</td>
#       <td id="T_f1e9c_row2_col3" class="data row2 col3" >binary</td>
#       <td id="T_f1e9c_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_f1e9c_row2_col5" class="data row2 col5" ></td>
#       <td id="T_f1e9c_row2_col6" class="data row2 col6" >keep</td>
#       <td id="T_f1e9c_row2_col7" class="data row2 col7" >no_missing</td>
#       <td id="T_f1e9c_row2_col8" class="data row2 col8" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_f1e9c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f1e9c_row3_col0" class="data row3 col0" >nmpd_diag</td>
#       <td id="T_f1e9c_row3_col1" class="data row3 col1" >predictor</td>
#       <td id="T_f1e9c_row3_col2" class="data row3 col2" >category</td>
#       <td id="T_f1e9c_row3_col3" class="data row3 col3" >categorical_nominal</td>
#       <td id="T_f1e9c_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_f1e9c_row3_col5" class="data row3 col5" ></td>
#       <td id="T_f1e9c_row3_col6" class="data row3 col6" >keep</td>
#       <td id="T_f1e9c_row3_col7" class="data row3 col7" >no_missing</td>
#       <td id="T_f1e9c_row3_col8" class="data row3 col8" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_f1e9c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f1e9c_row4_col0" class="data row4 col0" >dzimums</td>
#       <td id="T_f1e9c_row4_col1" class="data row4 col1" >predictor</td>
#       <td id="T_f1e9c_row4_col2" class="data row4 col2" >category</td>
#       <td id="T_f1e9c_row4_col3" class="data row4 col3" >categorical_nominal</td>
#       <td id="T_f1e9c_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_f1e9c_row4_col5" class="data row4 col5" ></td>
#       <td id="T_f1e9c_row4_col6" class="data row4 col6" >keep</td>
#       <td id="T_f1e9c_row4_col7" class="data row4 col7" >no_missing</td>
#       <td id="T_f1e9c_row4_col8" class="data row4 col8" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_f1e9c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f1e9c_row5_col0" class="data row5 col0" >GKS</td>
#       <td id="T_f1e9c_row5_col1" class="data row5 col1" >predictor</td>
#       <td id="T_f1e9c_row5_col2" class="data row5 col2" >category</td>
#       <td id="T_f1e9c_row5_col3" class="data row5 col3" >categorical_ordinal</td>
#       <td id="T_f1e9c_row5_col4" class="data row5 col4" >12.882206</td>
#       <td id="T_f1e9c_row5_col5" class="data row5 col5" ></td>
#       <td id="T_f1e9c_row5_col6" class="data row5 col6" >keep</td>
#       <td id="T_f1e9c_row5_col7" class="data row5 col7" >simple_impute</td>
#       <td id="T_f1e9c_row5_col8" class="data row5 col8" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_f1e9c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f1e9c_row6_col0" class="data row6 col0" >FastTest</td>
#       <td id="T_f1e9c_row6_col1" class="data row6 col1" >predictor</td>
#       <td id="T_f1e9c_row6_col2" class="data row6 col2" >category</td>
#       <td id="T_f1e9c_row6_col3" class="data row6 col3" >categorical_ordinal</td>
#       <td id="T_f1e9c_row6_col4" class="data row6 col4" >5.614035</td>
#       <td id="T_f1e9c_row6_col5" clas
# ══════════════════════════════════════════════════════════════════════════════════════════
# dropping bad cols...
# running simple impute...
# -> "GKS" is categorical so using mode
# GKS NaN-count: 12.88%->0.0%
# -> "FastTest" is categorical so using mode
# FastTest NaN-count: 5.61%->0.0%
# running advanced impute...
# ══════════════════════════════════════════════════════════════════════════════════════════
# # 🧠 Final Modeling Summary
#
# <span style="color:#7f8c8d;">Task:</span> **`Matching Ischemic Stroke`**
# <span style="color:#7f8c8d;">Positive class:</span> **`True`**
#
# ---
#
# ### 📊 Cohort Snapshot
# - <span style="color:#2980b9;">Rows:</span> **1,995**
# - <span style="color:#2980b9;">Columns:</span> **11**
# - <span style="color:#27ae60;">Target prevalence:</span> **0.518**
# - <span style="color:#8e44ad;">Predictors kept:</span> **10**
# ### 🎯 Class Counts
#    class     n
# 0   True  1034
# 1  False   961
# ### 🔬 Predictors by Inferred Type
# - **binary:** `izsaukuma_laiks_workday_bool`
# - **categorical_nominal:** `nmpd_diag`, `dzimums`
# - **categorical_ordinal:** `GKS`, `FastTest`, `izsaukuma_laiks_hour`, `izsaukuma_laiks_dow`, `izsaukuma_laiks_month_name`
# - **continuous:** `vecums`
# - **time_to_event:** `lidzPSKUS_timedelta_minutes`
# ### 🧪 Leakage Exclusions
# _No rows with notes._
# ### ⚠️ Main Warnings
# _No rows with notes._
# ══════════════════════════════════════════════════════════════════════
# 🧠 MODEL FRAME ONLINE
# ──────────────────────────────────────────────────────────────────────
# ✔ CLEAN (X, y) EXTRACTED
#    Shape         : 1995 rows x 11 cols
#    Remaining NaNs: 0 cells (0.00%)
#    Contents      : predictors after leakage/missingness rules + target.
#
# → Attending note: next step is baseline models, not more EDA.
#    vecums  izsaukuma_laiks_workday_bool nmpd_diag   dzimums GKS FastTest  \
# 0      92                         False       I64  vīrietis  14        3
# 4      76                          True       I64  sieviete  15        3
# 5      85                         False       I64  sieviete  13        4
# 6      72                          True       I64  sieviete  15        3
# 7      68                          True       I64  sieviete   9        4
#
#   izsaukuma_laiks_hour izsaukuma_laiks_dow izsaukuma_laiks_month_name  \
# 0                    8              Sunday                    January
# 4                   15           Wednesday                   February
# 5                   11            Saturday                      April
# 6                    7             Tuesday                     August
# 7                   19             Tuesday                  September
#
#    lidzPSKUS_timedelta_minutes  target
# 0                           61   False
# 4                           70   False
# 5                           77   False
# 6                           97   False
# 7                           57   False
# ℹ Set export=True to save model frame to data/processed/

# %% [markdown]
# -------------
# # 🧙‍♂️ **YLIVERTAINEN INFERENTIAL** 🧙‍♂️
# -------------

# %%
inferential = YlivertainenInferential(root, df_model, feature_decisions_df)
print(inferential)
# Out:
# ════════════════════════════════════════════════════════════════
# 🧠  YlivertainenInferential Briefing
# ════════════════════════════════════════════════════════════════
# 📌 Task                 inferential
# 🎯 Target               target
# ✅ Positive class       1
# 👥 Rows (n)             1,995
# 🧰 Predictors (model)   10
# 🧪 Predictors (approved) 10
# 📊 Inferential table    NOT RUN YET ⏳
# 🧭 Scope                Inferential scope is predictor -> target association only; no predictor-to-predictor claims and no causal claims.
#
# Methods
# • overview() / print(project) -> show this briefing
# • approved_predictor_columns() -> list approved predictors
# • run_inferential(...) -> build styled inferential table
#
# Stat map
# • continuous/discrete/time_to_event -> point-biserial r + bootstrap CI
# • binary/categorical -> Fisher/chi-square + Cramer's V + bootstrap CI
# • valid p-values -> Benjamini-Hochberg FDR
# • clinical flag -> moderate-or-larger effect size (default)
#
# Workflow
# • test predictor -> binary target only
# • skip unsupported, sparse, or degenerate predictors
# • build one tidy table with one row per predictor
# • color row text by FDR signal and clinical effect
# • requires explicit positive class lock by default
#
# Output columns
# • predictor, test_name, test_stat, effect_metric, effect_value, ci_low, ci_high, p_value, p_value_fdr, expected_cell_min, expected_cell_lt5_pct, expected_cell_warning, n, missing_pct, status, skipped_reason, fdr_significant, clinically_relevant
# ════════════════════════════════════════════════════════════════

# %%
inferential.run_inferential(
    positive_class=0,
    random_state=42,
    clinical_relevance_floor="moderate",
    export=False
    )
# Out:
# <style type="text/css">
# #T_85307_row0_col0, #T_85307_row0_col1, #T_85307_row0_col2, #T_85307_row0_col3, #T_85307_row0_col4, #T_85307_row0_col5, #T_85307_row0_col6, #T_85307_row0_col7, #T_85307_row0_col8, #T_85307_row0_col9, #T_85307_row0_col10, #T_85307_row0_col11, #T_85307_row0_col12, #T_85307_row0_col13, #T_85307_row0_col14, #T_85307_row0_col15, #T_85307_row0_col16, #T_85307_row0_col17, #T_85307_row1_col0, #T_85307_row1_col1, #T_85307_row1_col2, #T_85307_row1_col3, #T_85307_row1_col4, #T_85307_row1_col5, #T_85307_row1_col6, #T_85307_row1_col7, #T_85307_row1_col8, #T_85307_row1_col9, #T_85307_row1_col10, #T_85307_row1_col11, #T_85307_row1_col12, #T_85307_row1_col13, #T_85307_row1_col14, #T_85307_row1_col15, #T_85307_row1_col16, #T_85307_row1_col17, #T_85307_row2_col0, #T_85307_row2_col1, #T_85307_row2_col2, #T_85307_row2_col3, #T_85307_row2_col4, #T_85307_row2_col5, #T_85307_row2_col6, #T_85307_row2_col7, #T_85307_row2_col8, #T_85307_row2_col9, #T_85307_row2_col10, #T_85307_row2_col11, #T_85307_row2_col12, #T_85307_row2_col13, #T_85307_row2_col14, #T_85307_row2_col15, #T_85307_row2_col16, #T_85307_row2_col17 {
#   color: #c49000;
# }
# </style>
# <table id="T_85307">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85307_level0_col0" class="col_heading level0 col0" >predictor</th>
#       <th id="T_85307_level0_col1" class="col_heading level0 col1" >test_name</th>
#       <th id="T_85307_level0_col2" class="col_heading level0 col2" >test_stat</th>
#       <th id="T_85307_level0_col3" class="col_heading level0 col3" >effect_metric</th>
#       <th id="T_85307_level0_col4" class="col_heading level0 col4" >effect_value</th>
#       <th id="T_85307_level0_col5" class="col_heading level0 col5" >ci_low</th>
#       <th id="T_85307_level0_col6" class="col_heading level0 col6" >ci_high</th>
#       <th id="T_85307_level0_col7" class="col_heading level0 col7" >p_value</th>
#       <th id="T_85307_level0_col8" class="col_heading level0 col8" >p_value_fdr</th>
#       <th id="T_85307_level0_col9" class="col_heading level0 col9" >expected_cell_min</th>
#       <th id="T_85307_level0_col10" class="col_heading level0 col10" >expected_cell_lt5_pct</th>
#       <th id="T_85307_level0_col11" class="col_heading level0 col11" >expected_cell_warning</th>
#       <th id="T_85307_level0_col12" class="col_heading level0 col12" >n</th>
#       <th id="T_85307_level0_col13" class="col_heading level0 col13" >missing_pct</th>
#       <th id="T_85307_level0_col14" class="col_heading level0 col14" >status</th>
#       <th id="T_85307_level0_col15" class="col_heading level0 col15" >skipped_reason</th>
#       <th id="T_85307_level0_col16" class="col_heading level0 col16" >fdr_significant</th>
#       <th id="T_85307_level0_col17" class="col_heading level0 col17" >clinically_relevant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85307_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85307_row0_col0" class="data row0 col0" >lidzPSKUS_timedelta_minutes</td>
#       <td id="T_85307_row0_col1" class="data row0 col1" >mann_whitney_u</td>
#       <td id="T_85307_row0_col2" class="data row0 col2" >5.991e+05</td>
#       <td id="T_85307_row0_col3" class="data row0 col3" >rank_biserial_r</td>
#       <td id="T_85307_row0_col4" class="data row0 col4" >0.206</td>
#       <td id="T_85307_row0_col5" class="data row0 col5" >0.157</td>
#       <td id="T_85307_row0_col6" class="data row0 col6" >0.255</td>
#       <td id="T_85307_row0_col7" class="data row0 col7" >1.83e-15</td>
#       <td id="T_85307_row0_col8" class="data row0 col8" >1.83e-14</td>
#       <td id="T_85307_row0_col9" class="data row0 col9" >NA</td>
#       <td id="T_85307_row0_col10" class="data row0 col10" >NA</td>
#       <td id="T_85307_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_85307_row0_col12" class="data row0 col12" >1995</td>
#       <td id="T_85307_row0_col13" class="data row0 col13" >0.0</td>
#       <td id="T_85307_row0_col14" class="data row0 col14" >ok</td>
#       <td id="T_85307_row0_col15" class="data row0 col15" >NA</td>
#       <td id="T_85307_row0_col16" class="data row0 col16" >True</td>
#       <td id="T_85307_row0_col17" class="data row0 col17" >False</td>
#     </tr>
#     <tr>
#       <th id="T_85307_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85307_row1_col0" class="data row1 col0" >GKS</td>
#       <td id="T_85307_row1_col1" class="data row1 col1" >chi_square</td>
#       <td id="T_85307_row1_col2" class="data row1 col2" >65.24</td>
#       <td id="T_85307_row1_col3" class="data row1 col3" >cramers_v</td>
#       <td id="T_85307_row1_col4" class="data row1 col4" >0.181</td>
#       <td id="T_85307_row1_col5" class="data row1 col5" >0.157</td>
#       <td id="T_85307_row1_col6" class="data row1 col6" >0.229</td>
#       <td id="T_85307_row1_col7" class="data row1 col7" >2.463e-09</td>
#       <td id="T_85307_row1_col8" class="data row1 col8" >1.231e-08</td>
#       <td id="T_85307_row1_col9" class="data row1 col9" >3.372</td>
#       <td id="T_85307_row1_col10" class="data row1 col10" >7.7</td>
#       <td id="T_85307_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_85307_row1_col12" class="data row1 col12" >1995</td>
#       <td id="T_85307_row1_col13" class="data row1 col13" >0.0</td>
#       <td id="T_85307_row1_col14" class="data row1 col14" >ok</td>
#       <td id="T_85307_row1_col15" class="data row1 col15" >NA</td>
#       <td id="T_85307_row1_col16" class="data row1 col16" >True</td>
#       <td id="T_85307_row1_col17" class="data row1 col17" >False</td>
#     </tr>
#     <tr>
#       <th id="T_85307_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85307_row2_col0" class="data row2 col0" >FastTest</td>
#       <td id="T_85307_row2_col1" class="data row2 col1" >chi_square</td>
#       <td id="T_85307_row2_col2" class="data row2 col2" >13.36</td>
#       <td id="T_85307_row2_col3" class="data row2 col3" >cramers_v</td>
#       <td id="T_85307_row2_col4" class="data row2 col4" >0.082</td>
#       <td id="T_85307_row2_col5" class="data row2 col5" >0.048</td>
#       <td id="T_85307_row2_col6" class="data row2 col6" >0.127</td>
#       <td id="T_85307_row2_col7" class="data row2 col7" >0.003913</td>
#       <td id="T_85307_row2_col8" class="data row2 col8" >0.01304</td>
#       <td id="T_85307_row2_col9" class="data row2 col9" >85.743</td>
#       <td id="T_85307_row2_col10" class="data row2 col10" >0.0</td>
#       <td id="T_85307_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_85307_row2_col12" class="data row2 col12" >1995</td>
#       <td id="T_85307_row2_col13" class="data row2 col13" >0.0</td>
#       <td id="T_85307_row2_col14" class="data row2 col14" >ok</td>
#       <td id="T_85307_row2_col15" class="data row2 col15" >NA</td>
#       <td id="T_85307_row2_col16" class="data row2 col16" >True</td>
#       <td id="T_85307_row2_col17" class="data row2 col17" >False</td>
#     </tr>
#     <tr>
#       <th id="T_85307_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85307_row3_col0" class="data row3 col0" >izsaukuma_laiks_hour</td>
#       <td id="T_85307_row3_col1" class="data row3 col1" >chi_square</td>
#       <td id="T_85307_row3_col2" class="data row3 col2" >26.33</td>
#       <td id="T_85307_row3_col3" class="data row3 col3" >cramers_v</td>
#       <td id="T_85307_row3_col4" class="data row3 col4" >0.115</td>
#       <td id="T_85307_row3_col5" class="data row3 col5" >0.117</td>
#       <td id="T_85307_row3_col6" class="data row3 col6" >0.195</td>
#       <td id="T_85307_row3_col7" class="data row3 col7" >0.2854</td>
#       <td id="T_85307_row3_col8" class="data row3 col8" >0.4757</td>
#       <td id="T_85307_row3_col9" class="data row3 col9" >6.262</td>
#       <td id="T_85307_row3_col10" class="data row3 col10" >0.0</td>
#       <td id="T_85307_row3_col11" class="data row3 col11" >False</td>
#       <td id="T_85307_row3_col12" class="data row3 col12" >1995</td>
#       <td id="T_85307_row3_col13" class="data row3 col13" >0.0</td>
#       <td id="T_85307_row3_col14" class="data row3 col14" >o

# %% [markdown]
# -------------
# # 🤖 **YLIVERTAINEN PREDICTIVE** 🤖
# -------------

# %%
predictive = YlivertainenPredictive(root, df_model, feature_decisions_df, default_positive_class=1)
print(predictive)

predictive_outputs = predictive.run_predictive(
    test_size=0.20,
    cv_folds=5,
    n_boot=1000,
    ci_level=0.95,
    show_tables=True,
    export=False,
    threshold_strategy="min_sensitivity",
    min_sensitivity_target=0.80
)

predictive_outputs["final_metrics"]
# Out:
# ════════════════════════════════════════════════════════════════
# 🧠  YlivertainenPredictive Briefing
# ════════════════════════════════════════════════════════════════
# 📌 Task                 predictive
# 🎯 Target               target
# ✅ Positive class       1
# 👥 Rows (n)             1,995
# 🧰 Predictors (model)   10
# 🧪 Predictors (approved) 10
# 📊 Predictive artifacts NOT RUN YET ⏳
#
# Methods
# • overview() / print(project) -> show this briefing
# • approved_predictor_columns() -> list approved predictors
# • run_predictive(...) -> run model selection + final test evaluation
#
# Model strategy
# • leakage-safe preprocessing via ColumnTransformer inside each CV fold
# • candidate models: logistic regression, random forest, gradient boosting
# • hyperparameter search with stratified CV on train split only
# • untouched final test split for unbiased report metrics
# • test AUC CI by bootstrap + threshold sensitivity/specificity
#
# Output columns
# • model comparison: model_name, best_cv_auc_mean, best_cv_auc_std, best_params
# • final metrics: selected_model, threshold_strategy, threshold, test_auc, test_auc_ci_low, test_auc_ci_high, test_brier, test_sensitivity, test_specificity, test_tp, test_fp, test_tn, test_fn, n_train, n_test
# ════════════════════════════════════════════════════════════════
# Warning: top-2 model AUC gap (0.0025) < half of winner std (0.0148). Selection of 'random_forest' over 'gradient_boosting' is not conclusive.
#             model_name  best_cv_auc_mean  best_cv_auc_std  \
# 0        random_forest          0.634946         0.029608
# 1    gradient_boosting          0.632421         0.030508
# 2  logistic_regression          0.616786         0.022717
#
#                                          best_params
# 0  {'model__class_weight': None, 'model__max_dept...
# 1  {'model__learning_rate': 0.03, 'model__max_dep...
# 2  {'model__C': 0.1, 'model__class_weight': None,...
#   selected_model threshold_strategy  threshold  test_auc  test_auc_ci_low  \
# 0  random_forest    min_sensitivity      0.475  0.614382         0.552847
#
#    test_auc_ci_high  test_brier  test_sensitivity  test_specificity  test_tp  \
# 0          0.672469     0.23939          0.801932          0.348958      166
#
#    test_fp  test_tn  test_fn  n_train  n_test
# 0      125       67       41     1596     399
#   selected_model threshold_strategy  threshold  test_auc  test_auc_ci_low  \
# 0  random_forest    min_sensitivity      0.475  0.614382         0.552847
#
#    test_auc_ci_high  test_brier  test_sensitivity  test_specificity  test_tp  \
# 0          0.672469     0.23939          0.801932          0.348958      166
#
#    test_fp  test_tn  test_fn  n_train  n_test
# 0      125       67       41     1596     399

# %%
predictive.predictive_summary()
# Out:
# ## 🤖 Predictive Summary
#
# - **Task:** `predictive`
# - **Selected model:** `random_forest`
#
# ### 📈 Test Performance
# - <span style="color:#2563eb;"><b>ROC-AUC:</b></span> **`0.614`**
# - <span style="color:#2563eb;"><b>95% AUC CI:</b></span> **`0.553`** to **`0.672`**
# - <span style="color:#7c3aed;"><b>Threshold:</b></span> strategy **`min_sensitivity`**, value **`0.475`**
# - <span style="color:#16a34a;"><b>Sensitivity / Specificity:</b></span> **`0.802`** / **`0.349`**
# - <span style="color:#f59e0b;"><b>Brier score:</b></span> **`0.239`**
#
# ### 🧪 Candidate Model Comparison (CV ROC-AUC)
#             model_name  best_cv_auc_mean  best_cv_auc_std  \
# 0        random_forest          0.634946         0.029608
# 1    gradient_boosting          0.632421         0.030508
# 2  logistic_regression          0.616786         0.022717
#
#                                          best_params
# 0  {'model__class_weight': None, 'model__max_dept...
# 1  {'model__learning_rate': 0.03, 'model__max_dep...
# 2  {'model__C': 0.1, 'model__class_weight': None,...
# ### ✅ Final Test Confusion Counts
#
# - **TP / FP / TN / FN:** `166` / `125` / `67` / `41`
# - **Train/Test sizes:** `1596` / `399`

# %% [markdown]
# -------------
# # 💪🧠 **YLIVERTAINEN AWESOME REPORT** 💪🧠
# -------------

# %%
report = YlivertainenTheReport(
    root=root,
    metadata=metadata,
    cohorted_df=cohorted_df,
    feature_decisions_df=feature_decisions_df,
    df_model=df_model,
    predictive_outputs=predictive_outputs,
    # optional extras:
    dda_tables={
        "numerical": descriptive.numerical_DDA,
        "categorical": descriptive.categorical_DDA,
        "binary": descriptive.binary_DDA
        },
    associations_table=exploratory.associations_table,
    feature_importance_df=predictive.feature_importance_df,
)
report.generate()
# Out:
# ✅ Report saved → /Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/reports/Matching Ischemic Stroke_report.html
#    Size: 438 KB
# PosixPath('/Users/andriszaguzovs/TheLibraryOfCode/YlivertainenBadDataCraniotomy/ylivertainen/reports/Matching Ischemic Stroke_report.html')
